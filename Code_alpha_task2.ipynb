# %%
#IMPORT REQUIRED LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
from scipy.stats import ttest_ind

# %%
#LOAD THE DATASET

# %%
DF=pd.read_csv("/content/merged_index.csv")
DF
# Out:
#             date                 datetime cash_type                 card  \
# 0     2024-03-01  2024-03-01 10:15:50.520      card  ANON-0000-0000-0001
# 1     2024-03-01  2024-03-01 12:19:22.539      card  ANON-0000-0000-0002
# 2     2024-03-01  2024-03-01 12:20:18.089      card  ANON-0000-0000-0002
# 3     2024-03-01  2024-03-01 13:46:33.006      card  ANON-0000-0000-0003
# 4     2024-03-01  2024-03-01 13:48:14.626      card  ANON-0000-0000-0004
# ...          ...                      ...       ...                  ...
# 3891  2025-03-23      2025-03-23 14:55:46      cash                  NaN
# 3892  2025-03-23      2025-03-23 15:15:36      card                  NaN
# 3893  2025-03-23      2025-03-23 17:59:25      card                  NaN
# 3894  2025-03-23      2025-03-23 18:01:33      card                  NaN
# 3895  2025-03-23      2025-03-23 21:23:11      card                  NaN
#
#       money                 coffee_name
# 0      38.7                       Latte
# ...

# %%
#MEANINGFUL INFORMATION ABOUT THE DATASET

# %%
DF.head()
# Out:
#          date                 datetime cash_type                 card  money  \
# 0  2024-03-01  2024-03-01 10:15:50.520      card  ANON-0000-0000-0001   38.7
# 1  2024-03-01  2024-03-01 12:19:22.539      card  ANON-0000-0000-0002   38.7
# 2  2024-03-01  2024-03-01 12:20:18.089      card  ANON-0000-0000-0002   38.7
# 3  2024-03-01  2024-03-01 13:46:33.006      card  ANON-0000-0000-0003   28.9
# 4  2024-03-01  2024-03-01 13:48:14.626      card  ANON-0000-0000-0004   38.7
#
#      coffee_name
# 0          Latte
# 1  Hot Chocolate
# 2  Hot Chocolate
# 3      Americano
# 4          Latte

# %%
DF.tail()
# Out:
#             date             datetime cash_type card  money  \
# 3891  2025-03-23  2025-03-23 14:55:46      cash  NaN   30.0
# 3892  2025-03-23  2025-03-23 15:15:36      card  NaN   25.0
# 3893  2025-03-23  2025-03-23 17:59:25      card  NaN   28.0
# 3894  2025-03-23  2025-03-23 18:01:33      card  NaN   28.0
# 3895  2025-03-23  2025-03-23 21:23:11      card  NaN   29.0
#
#                      coffee_name
# 3891                  Cappuccino
# 3892               Irish whiskey
# 3893             Super chocolate
# 3894  Vanilla with Irish whiskey
# 3895   Coffee with Irish whiskey

# %%
#IDENTIFY VARIABLES AND DATA TYPES

# %%
DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3896 entries, 0 to 3895
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         3896 non-null   object
#  1   datetime     3896 non-null   object
#  2   cash_type    3896 non-null   object
#  3   card         3547 non-null   object
#  4   money        3896 non-null   float64
#  5   coffee_name  3896 non-null   object
# dtypes: float64(1), object(5)
# memory usage: 182.8+ KB

# %%
#STATISTICAL SUMMARY ABOUT THE DATASET

# %%
DF.describe()
# Out:
#              money
# count  3896.000000
# mean     31.383876
# std       5.063845
# min      15.000000
# 25%      27.920000
# 50%      32.820000
# 75%      35.760000
# max      40.000000

# %%
#IDENTIFY TRENDS AND PATTERN

# %%
DF['coffee_name'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='coffee_name'>

# %%
DF['money'].value_counts().plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
#HYPOTHESIS TESTING

# %%
Coffee = DF[DF['coffee_name']=="Latte"]['money']
name = DF[DF['coffee_name']=="Cocoa"]['money']
print(ttest_ind(Coffee,name))
# Out:
# TtestResult(statistic=np.float64(-1.167967090150313), pvalue=np.float64(0.24308593261173098), df=np.float64(1047.0))

# %%
#DETECT NULl AND ERROR VALUES

# %%
DF.isnull().sum()
# Out:
# date             0
# datetime         0
# cash_type        0
# card           349
# money            0
# coffee_name      0
# dtype: int64

# %%
DF.duplicated().sum()
# Out:
# np.int64(0)
